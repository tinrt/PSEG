# %%
import os
import json
import pandas as pd
import matplotlib.pyplot as plt
import folium
import geopandas as gpd

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Weighted Social Negative Index (WSNI)

# %%
df_score=pd.read_csv('/content/drive/MyDrive/PSEG Research Project/Social/social_sentiments_summary.csv')

# %%
w_pos = 0.2
w_neg = 0.6
w_neu = 0.2

def calculate_wn_sns(row):
    S_pos = row['Social Positive Count']
    S_neg = row['Social Negative Count']
    S_neu = row['Social Neutral Count']

    S_total = S_pos + S_neg + S_neu

    if S_total == 0:
        return 0

    N_pos = S_pos / S_total
    N_neg = S_neg / S_total
    N_neu = S_neu / S_total

    WN_pos = N_pos * w_pos
    WN_neg = N_neg * w_neg
    WN_neu = N_neu * w_neu

    WN_SNS = WN_neg - (WN_pos + WN_neu)
    return WN_SNS

df_score['WN-SNS'] = df_score.apply(calculate_wn_sns, axis=1)

# %%
df_score['WN-SNS']=df_score['WN-SNS']*100

# %% [markdown]
# ### Ranges and Scales of the WN-SNS
#
# The Weighted and Normalized Social Negative Score (WN-SNS) is designed to provide a nuanced measure of social sentiment, particularly the negative sentiment, relative to the total interactions. Understanding the ranges and scales of this score helps in interpreting the results effectively.
#
# #### 1. **Normalized Values Range**
#
# The normalized values (\(N_{pos}\), \(N_{neg}\), \(N_{neu}\)) are ratios, and their range is from 0 to 1.
#
# - If \(S_{pos} = 0\), \(N_{pos} = 0\).
# - If \(S_{neg} = 0\), \(N_{neg} = 0\).
# - If \(S_{neu} = 0\), \(N_{neu} = 0\).
#
# Conversely, if \(S_{pos}\), \(S_{neg}\), or \(S_{neu}\) are the only counts and the others are zero, their normalized value would be 1.
#
# #### 2. **Weighted Normalized Values Range**
#
# The weighted normalized values (\(WN_{pos}\), \(WN_{neg}\), \(WN_{neu}\)) also range from 0 to the weight assigned to them:
#
# - \(WN_{pos}\) ranges from 0 to \(w_{pos}\) (0.2 in this case).
# - \(WN_{neg}\) ranges from 0 to \(w_{neg}\) (0.6 in this case).
# - \(WN_{neu}\) ranges from 0 to \(w_{neu}\) (0.2 in this case).
#
# #### 3. **WN-SNS Score Range**
#
# The WN-SNS score can theoretically range from -0.4 to 0.6, given the weight configuration used:
#
# \[ \text{WN-SNS} = WN_{neg} - (WN_{pos} + WN_{neu}) \]
#
# - **Minimum Value**: When \(S_{neg} = 0\), \(S_{pos}\) and \(S_{neu}\) are at their maximum relative values (i.e., \(S_{pos} + S_{neu} = S_{total}\)), the minimum WN-SNS would be:
# \[ \text{WN-SNS}_{\min} = 0 - (0.2 + 0.2) = -0.4 \]
#
# - **Maximum Value**: When \(S_{pos} = 0\) and \(S_{neu} = 0\), and \(S_{neg} = S_{total}\), the maximum WN-SNS would be:
# \[ \text{WN-SNS}_{\max} = 0.6 - (0 + 0) = 0.6 \]
#
# #### 4. **Interpretation of the Scale**
#
# - **Positive WN-SNS**: Indicates a higher proportion of negative interactions compared to positive and neutral interactions. The closer the score is to 0.6, the more dominant the negative interactions are.
# - **Negative WN-SNS**: Indicates that positive and neutral interactions outweigh negative interactions. The closer the score is to -0.4, the more dominant the positive and neutral interactions are.
# - **WN-SNS near Zero**: Indicates a balance between negative, positive, and neutral interactions. A score close to zero suggests that no single type of interaction is overwhelmingly dominant.
#
# ### Practical Considerations
#
# 1. **Weight Adjustments**: The choice of weights (\(w_{pos}\), \(w_{neg}\), \(w_{neu}\)) significantly affects the WN-SNS. These should be chosen based on the specific context or desired emphasis in the analysis.
# 2. **Handling Zero Totals**: As previously noted, if \(S_{total} = 0\), the score should be set to a neutral value (e.g., 0) to avoid undefined behavior.
# 3. **Context-Specific Interpretation**: The interpretation of the WN-SNS should consider the context in which it is applied. For example, in a highly positive environment, even a slightly negative WN-SNS might be significant.
#
# By understanding these ranges and scales, the WN-SNS can be effectively used to measure and interpret social sentiment in a detailed and nuanced manner.

# %% [markdown]
# # Crime Index

# %%
df_crime=pd.read_excel('/content/drive/MyDrive/PSEG Research Project/Social/Crime.xls')

# %%
#df_score['Folder Name'] = df_score['Folder Name'].str.lower()
#df_crime['City'] = df_crime['City'].str.lower()

# %%
sum_columns = df_crime.iloc[:, 2:13].sum(axis=1)
result = sum_columns / df_crime['Population']
df_crime['Crime_Index'] = result

# %%
df_crime['Crime_Index']=df_crime['Crime_Index']*10000

# %%
df_crime['Crime_Index'].describe()
# Out:
# count      488.000000
# mean       374.233031
# std       1851.312891
# min          0.000000
# 25%        119.506142
# 50%        214.009083
# 75%        359.397622
# max      40588.235294
# Name: Crime_Index, dtype: float64

# %%
df_crime.to_csv('/content/drive/MyDrive/PSEG Research Project/Social/crime_index.csv', index=False)

# %%
df_crime.head()
# Out:
#                 City  Population  Violent\ncrime  \
# 0  Aberdeen Township     18378.0            11.0
# 1            Absecon      8252.0            17.0
# 2          Allendale      6865.0             3.0
# 3         Allenhurst       488.0             0.0
# 4          Allentown      1809.0             0.0
#
#    Murder and\nnonnegligent\nmanslaughter  Rape1  Robbery  \
# 0                                     0.0    2.0      2.0
# 1                                     1.0    1.0      5.0
# 2                                     0.0    1.0      0.0
# 3                                     0.0    0.0      0.0
# 4                                     0.0    0.0      0.0
#
#    Aggravated\nassault  Property\ncrime  Burglary  Larceny-\ntheft  \
# 0                  7.0            163.0      18.0            137.0
# 1                 10.0            181.0      16.0            159.0
# 2                  2.0             30.0       4.0             23.0
# 3                  0.0              7.0       0.0              4.0
# 4                  0.0              5.0       1.0              4.0
#
#    Motor\nvehicle\ntheft  Arson  Crime_Index
# 0                    8.0    0.0   189.356840
# 1                    6.0    0.0   479.883665
# 2                    3.0    0.0    96.139840
# 3                    3.0    0.0   286.885246
# 4                    0.0    0.0    55.279160

# %%
df_score.head()
# Out:
#            Folder Name  Social Positive Count  Social Negative Count  \
# 0    Aberdeen township                    104                     31
# 1         Absecon city                    213                     48
# 2  Alexandria township                     71                     32
# 3   Allamuchy township                    182                     25
# 4     Alloway township                     34                      3
#
#    Social Neutral Count    Average  Average_P_N  Scaled_Average_P_N     WN-SNS
# 0                   212  24.333333         36.5            0.208571 -12.853026
# 1                   275  55.000000         82.5            0.471429 -12.835821
# 2                   177  13.000000         19.5            0.111429 -10.857143
# 3                   238  52.333333         78.5            0.448571 -15.505618
# 4                    10  10.333333         15.5            0.088571 -14.893617

# %% [markdown]
# # Map

# %%
df_map=pd.read_csv("/content/drive/MyDrive/PSEG Research Project/New Jersey Areas/NJ_with_lat_long.csv")
#df_map['Municipality'] = df_map['Municipality'].str.lower()
df_map
# Out:
#             Municipality      County  MRI Score   Latitude  Longitude  \
# 0      Aberdeen township    Monmouth       2.33  40.407114 -74.221629
# 1           Absecon city    Atlantic      -2.94  39.436241 -74.517871
# 2    Alexandria township   Hunterdon       3.95  40.591417 -75.012824
# 3     Allamuchy township      Warren       4.03  40.921765 -74.810166
# 4       Alloway township       Salem       0.83  39.560857 -75.362397
# ..                   ...         ...        ...        ...        ...
# 348        Woodbury city  Gloucester      -6.38  39.845233 -75.147237
# 349    Woodland township  Burlington      -3.83  39.842075 -74.523058
# 350    Woodstown borough       Salem      -1.92  39.651287 -75.329138
# 351    Woolwich township  Gloucester       2.89  39.741482 -75.348055
# 352     Wyckoff township      Bergen       5.08  40.203446 -74.255701
#
#                                       Bing Search Link
# 0    https://www.bing.com/search?q=Aberdeen townshi...
# 1    https://www.bing.com/search?q=Absecon city+New...
# 2    https://www.bing.com/search?q=Alexandria towns...
# 3    https://www.bing.com/search?q=Allamuchy townsh...
# 4    https://www.bing.com/search?q=Alloway township...
# ..                                                 ...
# 348  https://www.bing.com/search?q=Woodbury city+Ne...
# 349  https://www.bing.com/search?q=Woodland townshi...
# 350  https://www.bing.com/search?q=Woodstown boroug...
# 351  https://www.bing.com/search?q=Woolwich townshi...
# 352  https://www.bing.com/search?q=Wyckoff township...
#
# [353 rows x 6 columns]

# %%
df_x = pd.merge(df_score, df_map, left_on='Folder Name', right_on='Municipality', how='inner')
df_x
# Out:
#              Folder Name  Social Positive Count  Social Negative Count  \
# 0      Aberdeen township                    104                     31
# 1           Absecon city                    213                     48
# 2    Alexandria township                     71                     32
# 3     Allamuchy township                    182                     25
# 4       Alloway township                     34                      3
# ..                   ...                    ...                    ...
# 348        Woodbury city                     45                      6
# 349    Woodland township                     23                      6
# 350    Woodstown borough                      8                      1
# 351    Woolwich township                     35                     11
# 352     Wyckoff township                     15                      6
#
#      Social Neutral Count    Average  Average_P_N  Scaled_Average_P_N  \
# 0                     212  24.333333         36.5            0.208571
# 1                     275  55.000000         82.5            0.471429
# 2                     177  13.000000         19.5            0.111429
# 3                     238  52.333333         78.5            0.448571
# 4                      10  10.333333         15.5            0.088571
# ..                    ...        ...          ...                 ...
# 348                    37  13.000000         19.5            0.111429
# 349                    42   5.666667          8.5            0.048571
# 350                     9   2.333333          3.5            0.020000
# 351                    33   8.000000         12.0            0.068571
# 352                    15   3.000000          4.5            0.025714
#
#         WN-SNS         Municipality      County  MRI Score   Latitude  \
# 0   -12.853026    Aberdeen township    Monmouth       2.33  40.407114
# 1   -12.835821         Absecon city    Atlantic      -2.94  39.436241
# 2   -10.857143  Alexandria township   Hunterdon       3.95  40.591417
# 3   -15.505618   Allamuchy township      Warren       4.03  40.921765
# 4   -14.893617     Alloway township       Salem       0.83  39.560857
# ..         ...                  ...         ...        ...        ...
# 348 -14.545455        Woodbury city  Gloucester      -6.38  39.845233
# 349 -13.239437    Woodland township  Burlington      -3.83  39.842075
# 350 -15.555556    Woodstown borough       Salem      -1.92  39.651287
# 351  -8.860759    Woolwich township  Gloucester       2.89  39.741482
# 352  -6.666667     Wyckoff township      Bergen       5.08  40.203446
#
#      Longitude                                   Bing Search Link
# 0   -74.221629  https://www.bing.com/search?q=Aberdeen townshi...
# 1   -74.517871  https://www.bing.com/search?q=Absecon city+New...
# 2   -75.012824  https://www.bing.com/search?q=Alexandria towns...
# 3   -74.810166  https://www.bing.com/search?q=Allamuchy townsh...
# 4   -75.362397  https://www.bing.com/search?q=Alloway township...
# ..         ...                                                ...
# 348 -75.147237  https://www.bing.com/search?q=Woodbury city+Ne...
# 349 -74.523058  https://www.bing.com/search?q=Woodland townshi...
# 350 -75.329138  https://www.bing.com/search?q=Woodstown boroug...
# 351 -75.348055  https://www.bing.com/search?q=Woolwich townshi...
# 352 -74.255701  https://www.bing.com/search?q=Wyckoff township...
#
# [353 rows x 14 columns]

# %%
df_x.columns
# Out:
# Index(['Folder Name', 'Social Positive Count', 'Social Negative Count',
#        'Social Neutral Count', 'Average', 'Average_P_N', 'Scaled_Average_P_N',
#        'WN-SNS', 'Municipality', 'County', 'MRI Score', 'Latitude',
#        'Longitude', 'Bing Search Link'],
#       dtype='object')

# %%
df_x=df_x[['Social Negative Count','WN-SNS', 'Municipality', 'County', 'MRI Score', 'Latitude',
       'Longitude']]

# %%
df_x.to_csv('sample.csv')

# %%
SN_geo_cri=pd.read_csv('/content/drive/MyDrive/PSEG Research Project/Social/SN_geo_cri.csv')

# %%
SN_geo_cri
# Out:
#      Unnamed: 0  Social Negative Count     WN-SNS       Municipality  \
# 0             0                     31 -12.853026  aberdeen township
# 1             1                     48 -12.835821       absecon city
# 2             5                     37 -13.051643    andover borough
# 3             6                      7 -12.911392   andover township
# 4             7                     24 -13.663366      atlantic city
# ..          ...                    ...        ...                ...
# 285         348                      6 -14.545455      woodbury city
# 286         349                      6 -13.239437  woodland township
# 287         350                      1 -15.555556  woodstown borough
# 288         351                     11  -8.860759  woolwich township
# 289         352                      6  -6.666667   wyckoff township
#
#          County  MRI Score   Latitude  Longitude  Crime_Index
# 0      Monmouth       2.33  40.407114 -74.221629   189.356840
# 1      Atlantic      -2.94  39.436241 -74.517871   479.883665
# 2        Sussex      -1.39  40.988875 -74.741991    53.908356
# 3        Sussex       0.94  41.015609 -74.729750    55.279160
# 4      Atlantic     -20.13  39.364285 -74.422935   761.673330
# ..          ...        ...        ...        ...          ...
# 285  Gloucester      -6.38  39.845233 -75.147237   976.810999
# 286  Burlington      -3.83  39.842075 -74.523058   248.456911
# 287       Salem      -1.92  39.651287 -75.329138   278.503046
# 288  Gloucester       2.89  39.741482 -75.348056    79.138968
# 289      Bergen       5.08  40.203446 -74.255701   105.471709
#
# [290 rows x 9 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
import folium
import geopandas as gpd
from matplotlib import cm
from matplotlib.colors import Normalize
import matplotlib.colors as colors
from branca.element import Template, MacroElement

df_x = SN_geo_cri
df_x['Municipality'] = df_x['Municipality'].str.title()

total_sum = df_x['Social Negative Count'].sum()

df_x['SN_ratio'] = df_x['Social Negative Count'] / total_sum

vmin = np.percentile(df_x['WN-SNS'], 10)
vmax = np.percentile(df_x['WN-SNS'], 90)

norm = colors.Normalize(vmin=vmin, vmax=vmax)

color_map = cm.ScalarMappable(norm=norm, cmap='coolwarm')

m = folium.Map(location=[40.0583, -74.4057], zoom_start=8)

for idx, row in df_x.iterrows():
    color = color_map.to_rgba(row['WN-SNS'])
    color_hex = colors.to_hex(color)

    popup = folium.Popup(
        f"<b>Area:</b> {row['Municipality']}<br><b>Weighted Social Negative Index (WSNI):</b> {row['WN-SNS']}<br><b>Crime index:</b> {row['Crime_Index']}<br><b>Social Negative Articles Ratio:</b> {row['SN_ratio']}",
        max_width=300
    )

    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup,
        icon=folium.Icon(color="gray", icon_color=color_hex)  # Set icon color to gray for visibility, but actual marker color will be from color
    ).add_to(m)



legend_html = '''
<div style="
    position: fixed;
    bottom: 50px; left: 50px; width: 300px; height: auto;
    border:2px solid grey; z-index:9999; font-size:14px;
    background-color:white; padding: 10px;
">
    <b>Legend</b><br>
    <b>Weighted Social Negative Index (WSNI):</b> Measure of social sentiment, particularly the negative sentiment, relative to the total interactions. Larger WSNI indicates a higher proportion of negative interactions compared to positive and neutral interactions.<br>
    <b>Crime index:</b> Total number of reported crimes divided by population.<br>
    <b>Social Negative Articles Ratio:</b> Ratio of the total number of social negative articles in this area to the total number of social negative articles.
</div>
'''

legend = MacroElement()
legend._template = Template(legend_html)
m.get_root().add_child(legend)
m.save('WN_SNS_map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8024b1f3a6c017561f76ac31356e9a70 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8024b1f3a6c017561f76ac31356e9a70&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8024b1f3a6c017561f76ac31356e9a70 = L.map(
#                 &quot;map_8024b1f3a6c017561f76ac31356e9a70&quot;,
#                 {
#                     center: [40.0583, -74.4057],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db9bca13b819f277c58795d950ed408b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_db9bca13b819f277c58795d950ed408b.addTo(map_8024b1f3a6c017561f76ac31356e9a70);
#
#
#             var marker_0cef4f368dfbe5eee9e58a13e7333530 = L.marker(
#                 [40.4071138, -74.2216287],
#                 {}
#             ).addTo(map_8024b1f3a6c017561f76ac31356e9a70);
#
#
#             var icon_175c7e8db5fada3fcc69c9768d4f2b8f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;#7a9df8&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0cef4f368dfbe5eee9e58a13e7333530.setIcon(icon_175c7e8db5fada3fcc69c9768d4f2b8f);
#
#
#         var popup_7ea56196f57ad87a28f3efddc81f95c1 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_340ee9e2543e61da6e38adaa3e98e698 = $(`&lt;div id=&quot;html_340ee9e2543e61da6e38adaa3e98e698&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Area:&lt;/b&gt; Aberdeen Township&lt;br&gt;&lt;b&gt;Weighted Social Negative Index (WSNI):&lt;/b&gt; -12.85302594&lt;br&gt;&lt;b&gt;Crime index:&lt;/b&gt; 189.3568397&lt;br&gt;&lt;b&gt;Social Negative Articles Ratio:&lt;/b&gt; 0.00389545111837145&lt;/div&gt;`)[0];
#                 popup_7ea56196f57ad87a28f3efddc81f95c1.setContent(html_340ee9e2543e61da6e38adaa3e98e698);
#
#
#
#         marker_0cef4f368dfbe5eee9e58a13e7333530.bindPopup(popup_7ea56196f57ad87a28f3efddc81f95c1)
#         ;
#
#
#
#
#             var marker_21b7c9b7aa1e851ef1d24e23c404801b = L.marker(
#                 [39.43624115, -74.51787132],
#                 {}
#             ).addTo(map_8024b1f3a6c017561f76ac31356e9a70);
#
#
#             var icon_14cd0860304417e683bacdce509e3f0e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;#7b9ff9&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_21b7c9b7aa1e851ef1d24e23c404801b.setIcon(icon_14cd0860304417e683bacdce509e3f0e);
#
#
#         var popup_381d8b0c53561ea7e1cf2fbfa1369d69 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_e5f0110930e875bb8f0f334ade4a2299 = $(`&lt;div id=&quot;html_e5f0110930e875bb8f0f334ade4a2299&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Area:&lt;/b&gt; Absecon City&lt;br&gt;&lt;b&gt;Weighted Social Negative Index (WSNI):&lt;/b&gt; -12.8358209&lt;br&gt;&lt;b&gt;Crime index:&lt;/b&gt; 479.8836646&lt;br&gt;&lt;b&gt;Social Negative Articles Ratio:&lt;/b&gt; 0.006031666247800955&lt;/div&gt;`)[0];
#                 popup_381d8b0c53561ea7e1cf2fbfa1369d69.setContent(html_e5f0110930e875bb8f0f334ade4a2299);
#
#
#
#         marker_21b7c9b7aa1e851ef1d24e23c404801b.bindPopup(popup_381d8b0c53561ea7e1cf2fbfa1369d69)
#         ;
#
#
#
#
#             var marker_8fc6e14cf19407f057d54ba3ebe56865 = L.marker(
#                 [40.98887495, -74.74199104],
#                 {}
#             ).addTo(map_8024b1f3a6c017561f76ac31356e9a70);
#
#
#             var icon_d7ada3363b567ef1026a225d018164b7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;#7699f6&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8fc6e14cf19407f057d54ba3ebe56865.setIcon(icon_d7ada3363b567ef1026a225d018164b7);
#
#
#         var popup_d3910a7ff2495b9288d8d5200d469529 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_d03fcf49492ef4dc4c76f9f0a44959d1 = $(`&lt;div id=&quot;html_d03fcf49492ef4dc4c76f9f0a44959d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Area:&lt;/b&gt; Andover Borough&lt;br&gt;&lt;b&gt;Weighted Social Negative Index (WSNI):&lt;/b&gt; -13.05164319&lt;br&gt;&lt;b&gt;Crime index:&lt;/b&gt; 53.9083558&lt;br&gt;&lt;b&gt;Social Negative Articles Ratio:&lt;/b&gt; 0.00464940939934657&lt;/div&gt;`)[0

# %%
import numpy as np
import matplotlib.pyplot as plt
import folium
import geopandas as gpd
from matplotlib import cm
from matplotlib.colors import Normalize
import matplotlib.colors as colors
from branca.element import Template, MacroElement

df_x = SN_geo_cri
df_x['Municipality'] = df_x['Municipality'].str.title()

total_sum = df_x['Social Negative Count'].sum()

df_x['SN_ratio'] = df_x['Social Negative Count'] / total_sum

vmin = np.percentile(df_x['Crime_Index'], 10)
vmax = np.percentile(df_x['Crime_Index'], 90)

norm = colors.Normalize(vmin=vmin, vmax=vmax)

color_map = cm.ScalarMappable(norm=norm, cmap='PRGn')

m = folium.Map(location=[40.0583, -74.4057], zoom_start=8)

for idx, row in df_x.iterrows():
    color = color_map.to_rgba(row['Crime_Index'])
    color_hex = colors.to_hex(color)

    popup = folium.Popup(
        f"<b>Area:</b> {row['Municipality']}<br><b>Crime index:</b> {row['Crime_Index']}<br><b>Weighted Social Negative Index (WSNI)</b> {row['Crime_Index']}<br><b>Social Negative Articles Ratio:</b> {row['SN_ratio']}",
        max_width=300  # Adjust the max width as needed
    )

    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup,
        icon=folium.Icon(color="gray", icon_color=color_hex)
    ).add_to(m)


m
#m.save('Crime_map.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2fe1a47650d072e86d68e41ccd64e44 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2fe1a47650d072e86d68e41ccd64e44&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a2fe1a47650d072e86d68e41ccd64e44 = L.map(
#                 &quot;map_a2fe1a47650d072e86d68e41ccd64e44&quot;,
#                 {
#                     center: [40.0583, -74.4057],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a784a1777820be85c94bd4652d9aaab6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a784a1777820be85c94bd4652d9aaab6.addTo(map_a2fe1a47650d072e86d68e41ccd64e44);
#
#
#             var marker_c1f94c9c93fa264eb84dd3120f0d2701 = L.marker(
#                 [40.4071138, -74.2216287],
#                 {}
#             ).addTo(map_a2fe1a47650d072e86d68e41ccd64e44);
#
#
#             var icon_7190bdf63b6fb0fbc458a81d993e7101 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;#a681b6&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c1f94c9c93fa264eb84dd3120f0d2701.setIcon(icon_7190bdf63b6fb0fbc458a81d993e7101);
#
#
#         var popup_0fb1f396b47b5c1731ae7bc0575246c0 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_6ce81f3eff5b3d79246b1ca2b42e1c81 = $(`&lt;div id=&quot;html_6ce81f3eff5b3d79246b1ca2b42e1c81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Area:&lt;/b&gt; Aberdeen Township&lt;br&gt;&lt;b&gt;Crime index:&lt;/b&gt; 189.3568397&lt;br&gt;&lt;b&gt;Weighted Social Negative Index (WSNI)&lt;/b&gt; 189.3568397&lt;br&gt;&lt;b&gt;Social Negative Articles Ratio:&lt;/b&gt; 0.00389545111837145&lt;/div&gt;`)[0];
#                 popup_0fb1f396b47b5c1731ae7bc0575246c0.setContent(html_6ce81f3eff5b3d79246b1ca2b42e1c81);
#
#
#
#         marker_c1f94c9c93fa264eb84dd3120f0d2701.bindPopup(popup_0fb1f396b47b5c1731ae7bc0575246c0)
#         ;
#
#
#
#
#             var marker_9c1e617c8462fb4849ee2f1cf6fc5164 = L.marker(
#                 [39.43624115, -74.51787132],
#                 {}
#             ).addTo(map_a2fe1a47650d072e86d68e41ccd64e44);
#
#
#             var icon_a114a741931c6cfa0d261f49de5f13e8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;#2b8642&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9c1e617c8462fb4849ee2f1cf6fc5164.setIcon(icon_a114a741931c6cfa0d261f49de5f13e8);
#
#
#         var popup_a2f65f6f1739b109286404abe7b641c1 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_7bfe50ea58a8e58d444bdfb7dd8263bf = $(`&lt;div id=&quot;html_7bfe50ea58a8e58d444bdfb7dd8263bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Area:&lt;/b&gt; Absecon City&lt;br&gt;&lt;b&gt;Crime index:&lt;/b&gt; 479.8836646&lt;br&gt;&lt;b&gt;Weighted Social Negative Index (WSNI)&lt;/b&gt; 479.8836646&lt;br&gt;&lt;b&gt;Social Negative Articles Ratio:&lt;/b&gt; 0.006031666247800955&lt;/div&gt;`)[0];
#                 popup_a2f65f6f1739b109286404abe7b641c1.setContent(html_7bfe50ea58a8e58d444bdfb7dd8263bf);
#
#
#
#         marker_9c1e617c8462fb4849ee2f1cf6fc5164.bindPopup(popup_a2f65f6f1739b109286404abe7b641c1)
#         ;
#
#
#
#
#             var marker_7f0f999fd526fbbf260c0ebfbee164e8 = L.marker(
#                 [40.98887495, -74.74199104],
#                 {}
#             ).addTo(map_a2fe1a47650d072e86d68e41ccd64e44);
#
#
#             var icon_9faf6bd65c671fbf5c779d6845d4cd2b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;#40004b&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7f0f999fd526fbbf260c0ebfbee164e8.setIcon(icon_9faf6bd65c671fbf5c779d6845d4cd2b);
#
#
#         var popup_fb3fe71a09b4ae7677c017c456ec5c34 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_f23a4219527b92a5271e16681b0a66ac = $(`&lt;div id=&quot;html_f23a4219527b92a5271e16681b0a66ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Area:&lt;/b&gt; Andover Borough&lt;br&gt;&lt;b&gt;Crime index:&lt;/b&gt; 53.9083558&lt;br&gt;&lt;b&gt;Weighted Social Negative Index (WSNI)&lt;/b&gt; 53.9083558&lt;br&gt;&lt;b&gt;Social Negative Articles Ratio:&lt;/b&gt; 0.00464940939934657&lt;/div&gt;`)[0];
